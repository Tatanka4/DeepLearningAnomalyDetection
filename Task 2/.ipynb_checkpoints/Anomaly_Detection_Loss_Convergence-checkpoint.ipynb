# %% [markdown]
# # Deep Learning - Anomaly Detection
# ### **Task 2**
#
# | Componente | Matricola |
# | --- | --- |
# | Gianfranco Sapia | 223954 |
# | Andrea De Seta | 227755 |

# %% [markdown]
# ## **Data Understanding**

# %%
import os
import numpy as np

# %% [markdown]
# #### **Load dataset**

# %%
"""from google.colab import drive
drive.mount('/content/drive')"""
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
#train_path = '/content/drive/MyDrive/Deep Learning Project/Task 2/ad_train.csv' #only for colab
#test_path = '/content/drive/MyDrive/Deep Learning Project/Task 2/ad_test.csv' #only for colab

train_path = 'ad_train.csv'
test_path = 'ad_test.csv'

# %%
import pandas as pd

train_data_loaded = pd.read_csv(train_path)
test_data_loaded = pd.read_csv(test_path)
train_data_loaded
# Out:
#         patient    x    y    z  heartRate      timestamp  \
# 0          1502   23  569  878         -1  1568073600000
# 1          1502   23  571  878         -1  1568073601000
# 2          1502   23  570  878         -1  1568073602000
# 3          1502   23  570  878         -1  1568073603000
# 4          1502   23  570  878         -1  1568073604000
# ...         ...  ...  ...  ...        ...            ...
# 943517     4506 -636 -399 -654         57  1572479994000
# 943518     4506 -639 -396 -654         57  1572479995000
# 943519     4506 -638 -396 -655         57  1572479996000
# 943520     4506 -637 -396 -655         58  1572479997000
# 943521     4506 -636 -399 -656         58  1572479998000
#
#                          tsDate
# 0       2019-09-10 00:00:00.003
# 1       2019-09-10 00:00:01.014
# 2       2019-09-10 00:00:02.025
# 3       2019-09-10 00:00:03.035
# 4       2019-09-10 00:00:04.046
# ...                         ...
# 943517  2019-10-30 23:59:54.315
# 943518  2019-10-30 23:59:55.316
# 943519  2019-10-30 23:59:56.336
# 943520  2019-10-30 23:59:57.337
# 943521  2019-10-30 23:59:58.338
#
# [943522 rows x 7 columns]

# %% [markdown]
# ##### **Data dimension**

# %%
train_data_loaded.size
# Out:
# 6604654

# %%
train_data_loaded.shape
# Out:
# (943522, 7)

# %% [markdown]
# ##### **Get attribute type and general statistics**

# %%
train_data_loaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943522 entries, 0 to 943521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   patient    943522 non-null  int64
#  1   x          943522 non-null  int64
#  2   y          943522 non-null  int64
#  3   z          943522 non-null  int64
#  4   heartRate  943522 non-null  int64
#  5   timestamp  943522 non-null  int64
#  6   tsDate     943522 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 50.4+ MB

# %%
train_data_loaded.describe()
# Out:
#              patient              x              y              z  \
# count  943522.000000  943522.000000  943522.000000  943522.000000
# mean     2965.730395     -82.993777     265.351292    -203.930526
# std      1318.330121     577.033231     539.747675     534.955382
# min      1502.000000   -1649.000000   -1082.000000   -1256.000000
# 25%      1505.000000    -532.000000     -59.000000    -665.000000
# 50%      3507.000000     -91.000000     313.000000    -223.000000
# 75%      4502.000000     311.000000     739.000000     125.000000
# max      4506.000000    1796.000000    1644.000000    1127.000000
#
#            heartRate     timestamp
# count  943522.000000  9.435220e+05
# mean       70.203571  1.570917e+12
# std        20.973755  2.063158e+09
# min        -1.000000  1.568074e+12
# 25%        61.000000  1.568135e+12
# 50%        70.000000  1.572414e+12
# 75%        82.000000  1.572447e+12
# max       182.000000  1.572480e+12

# %%
train_data_loaded['x'] = train_data_loaded['x'].astype('float64')
train_data_loaded['y'] = train_data_loaded['y'].astype('float64')
train_data_loaded['z'] = train_data_loaded['z'].astype('float64')
train_data_loaded['heartRate'] = train_data_loaded['heartRate'].astype('float64')
train_data_loaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943522 entries, 0 to 943521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   patient    943522 non-null  int64
#  1   x          943522 non-null  float64
#  2   y          943522 non-null  float64
#  3   z          943522 non-null  float64
#  4   heartRate  943522 non-null  float64
#  5   timestamp  943522 non-null  int64
#  6   tsDate     943522 non-null  object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 50.4+ MB

# %%
id_patients = train_data_loaded['patient'].values
id_patients = np.unique(id_patients)
id_patients
# Out:
# array([1502, 1503, 1505, 1507, 1509, 3506, 3507, 3508, 3509, 4502, 4504,
#        4505, 4506], dtype=int64)

# %% [markdown]
# ##### **Data visualization**

# %%
import matplotlib.pyplot as plt

for id in id_patients:
  heartrate = train_data_loaded['heartRate'].where(train_data_loaded['patient'] == id)
  fig = plt.figure(figsize=(15, 8))
  plt.plot(heartrate)
  plt.title(id)

# %%
ids_missing_hr = [1502, 1505, 1507, 3509, 4504, 4505]

# %%
timeslots = []
for id in ids_missing_hr:
  filter1 = train_data_loaded['patient'] == id
  filter2 = train_data_loaded['heartRate'] == -1
  timeslot = train_data_loaded['tsDate'].where(filter1 & filter2).dropna()
  timeslots.append(timeslot)

# %%
timeslots[1].index[0]
# Out:
# 217619

# %%
from datetime import datetime

for ts in timeslots:
  last_date = ts.values[-1]
  first_date = ts.values[0]
  last = datetime.strptime(last_date, "%Y-%m-%d %H:%M:%S.%f")
  first = datetime.strptime(first_date, "%Y-%m-%d %H:%M:%S.%f")
  print("Initial time :" + str(first))
  print("Last time :" + str(last))
  print("Time passed :" + str(last-first) + "\n")
# Out:
# Initial time :2019-09-10 00:00:00.003000
# Last time :2019-09-10 01:59:58.395000
# Time passed :1:59:58.392000
#
# Initial time :2019-09-10 14:00:00.007000
# Last time :2019-09-10 14:59:58.542000
# Time passed :0:59:58.535000
#
# Initial time :2019-09-10 19:00:00.016000
# Last time :2019-09-10 20:59:58.105000
# Time passed :1:59:58.089000
#
# Initial time :2019-10-30 06:00:00.005000
# Last time :2019-10-30 07:59:58.754000
# Time passed :1:59:58.749000
#
# Initial time :2019-10-30 15:00:00.012000
# Last time :2019-10-30 17:59:58.767000
# Time passed :2:59:58.755000
#
# Initial time :2019-10-30 20:00:00.002000
# Last time :2019-10-30 20:59:58.327000
# Time passed :0:59:58.325000

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ##### **Patient series split**
# Nella cella sottostante verrà ricreato l'array con le sequenze per ogni paziente dove però le series dei pazienti con dei valori di "Heartrate" a -1 verranno considerate come due series: una a sinistra dei valori di "-1" ed una a destra dei valori di "-1"

# %%
new_data = []

filter_hr = train_data_loaded['heartRate'] == -1
for id in id_patients:
  
  filter_id = train_data_loaded['patient'] == id
  
  series = train_data_loaded.where(filter_id).dropna()
  
  if id in ids_missing_hr:
    missing_hr_row = train_data_loaded.where(filter_id & filter_hr).dropna()

    left_series = train_data_loaded[series.index[0]:missing_hr_row.index[0]]
    right_series = train_data_loaded[missing_hr_row.index[-1]+1:series.index[-1]]

    if (len(left_series)) != 0:
        new_data.append(left_series)
    
    if (len(right_series)) != 0:
        new_data.append(right_series)
    #pass
  else:
    new_data.append(series)

# %%
new_data
# Out:
# [       patient      x      y      z  heartRate      timestamp  \
#  7120      1502   23.0  570.0  878.0       84.0  1568080800000
#  7121      1502   23.0  571.0  878.0       84.0  1568080801000
#  7122      1502   23.0  571.0  878.0       84.0  1568080802000
#  7123      1502   23.0  571.0  877.0       84.0  1568080803000
#  7124      1502   23.0  571.0  878.0       84.0  1568080804000
#  ...        ...    ...    ...    ...        ...            ...
#  85238     1502  301.0 -851.0  516.0       50.0  1568159992000
#  85239     1502  300.0 -851.0  514.0       50.0  1568159994000
#  85240     1502  300.0 -851.0  515.0       50.0  1568159995000
#  85241     1502  300.0 -850.0  515.0       50.0  1568159996000
#  85242     1502  300.0 -851.0  516.0       50.0  1568159997000
#
#                          tsDate
#  7120   2019-09-10 02:00:00.000
#  7121   2019-09-10 02:00:01.010
#  7122   2019-09-10 02:00:02.022
#  7123   2019-09-10 02:00:03.033
#  7124   2019-09-10 02:00:04.376
#  ...                        ...
#  85238  2019-09-10 23:59:52.994
#  85239  2019-09-10 23:59:54.006
#  85240  2019-09-10 23:59:55.018
#  85241  2019-09-10 23:59:56.032
#  85242  2019-09-10 23:59:57.044
#
#  [78123 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  85244    1503.0  583.0 -689.0 -439.0       60.0  1.568074e+12
#  85245    1503.0  579.0 -690.0 -442.0       59.0  1.568074e+12
#  85246    1503.0  580.0 -691.0 -442.0       60.0  1.568074e+12
#  85247    1503.0  584.0 -689.0 -439.0       60.0  1.568074e+12
#  85248    1503.0  581.0 -691.0 -441.0       60.0  1.568074e+12
#  ...         ...    ...    ...    ...        ...           ...
#  167879   1503.0  597.0 -618.0 -522.0       77.0  1.568160e+12
#  167880   1503.0  595.0 -618.0 -526.0       77.0  1.568160e+12
#  167881   1503.0  596.0 -618.0 -522.0       76.0  1.568160e+12
#  167882   1503.0  597.0 -617.0 -524.0       75.0  1.568160e+12
#  167883   1503.0  595.0 -617.0 -525.0       75.0  1.568160e+12
#
#                           tsDate
#  85244   2019-09-10 00:00:00.019
#  85245   2019-09-10 00:00:01.025
#  85246   2019-09-10 00:00:02.031
#  85247   2019-09-10 00:00:03.037
#  85248   2019-09-10 00:00:04.042
#  ...                         ...
#  167879  2019-09-10 23:59:54.107
#  167880  2019-09-10 23:59:55.112
#  167881  2019-09-10 23:59:56.119
#  167882  2019-09-10 23:59:57.124
#  167883  2019-09-10 23:59:58.129
#
#  [82640 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  167884     1505 -388.0  773.0 -504.0       57.0  1568073600000
#  167885     1505 -387.0  773.0 -504.0       57.0  1568073601000
#  167886     1505 -386.0  774.0 -503.0       56.0  1568073602000
#  167887     1505 -387.0  773.0 -504.0       56.0  1568073603000
#  167888     1505 -387.0  772.0 -505.0       55.0  1568073604000
#  ...         ...    ...    ...    ...        ...            ...
#  217614     1505 -953.0  -30.0  225.0       59.0  1568123993000
#  217615     1505 -953.0  -31.0  225.0       59.0  1568123994000
#  217616     1505 -952.0  -31.0  225.0       59.0  1568123995000
#  217617     1505 -953.0  -31.0  225.0       59.0  1568123996000
#  217618     1505 -953.0  -31.0  225.0       59.0  1568123997000
#
#                           tsDate
#  167884  2019-09-10 00:00:00.014
#  167885  2019-09-10 00:00:01.022
#  167886  2019-09-10 00:00:02.029
#  167887  2019-09-10 00:00:03.036
#  167888  2019-09-10 00:00:04.044
#  ...                         ...
#  217614  2019-09-10 13:59:53.960
#  217615  2019-09-10 13:59:54.968
#  217616  2019-09-10 13:59:55.975
#  217617  2019-09-10 13:59:56.983
#  217618  2019-09-10 13:59:57.991
#
#  [49735 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  221185     1505 -953.0  -31.0  219.0       68.0  1568127600000
#  221186     1505 -954.0  -31.0  219.0       68.0  1568127601000
#  221187     1505 -953.0  -31.0  218.0       68.0  1568127602000
#  221188     1505 -952.0  -32.0  218.0       68.0  1568127603000
#  221189     1505 -953.0  -32.0  220.0       68.0  1568127604000
#  ...         ...    ...    ...    ...        ...            ...
#  252049     1505 -731.0 -609.0 -183.0       63.0  1568159993000
#  252050     1505 -731.0 -610.0 -182.0       63.0  1568159994000
#  252051     1505 -731.0 -609.0 -183.0       63.0  1568159995000
#  252052     1505 -732.0 -609.0 -182.0       63.0  1568159996000
#  252053     1505 -732.0 -609.0 -182.0       63.0  1568159997000
#
#                           tsDate
#  221185  2019-09-10 15:00:00.013
#  221186  2019-09-10 15:00:01.021
#  221187  2019-09-10 15:00:02.029
#  221188  2019-09-10 15:00:03.035
#  221189  2019-09-10 15:00:04.044
#  ...                         ...
#  252049  2019-09-10 23:59:53.418
#  252050  2019-09-10 23:59:54.426
#  252051  2019-09-10 23:59:55.433
#  252052  2019-09-10 23:59:56.441
#  252053  2019-09-10 23:59:57.448
#
#  [30869 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  252055     1507 -441.0  401.0 -813.0       75.0  1568073600000
#  252056     1507 -439.0  405.0 -814.0       75.0  1568073601000
#  252057     1507 -438.0  408.0 -813.0       76.0  1568073602000
#  252058     1507 -439.0  405.0 -813.0       76.0  1568073603000
#  252059     1507 -436.0  407.0 -814.0       76.0  1568073604000
#  ...         ...    ...    ...    ...        ...            ...
#  316892     1507 -978.0  -52.0   87.0       68.0  1568141994000
#  316893     1507 -977.0  -53.0   86.0       68.0  1568141995000
#  316894     1507 -978.0  -51.0   87.0       68.0  1568141996000
#  316895     1507 -979.0  -54.0   86.0       68.0  1568141997000
#  316896     1507 -979.0  -51.0   86.0       68.0  1568141998000
#
#                           tsDate
#  252055  2019-09-10 00:00:00.013
#  252056  2019-09-10 00:00:01.029
#  252057  2019-09-10 00:00:02.045
#  252058  2019-09-10 00:00:03.061
#  252059  2019-09-10 00:00:04.067
#  ...                         ...
#  316892  2019-09-10 18:59:54.357
#  316893  2019-09-10 18:59:55.375
#  316894  2019-09-10 18:59:56.393
#  316895  2019-09-10 18:59:57.410
#  316896  2019-09-10 18:59:58.428
#
#  [64842 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  323974     1507 -977.0  -52.0   85.0       76.0  1568149200000
#  323975     1507 -979.0  -53.0   86.0       76.0  1568149201000
#  323976     1507 -978.0  -52.0   87.0       76.0  1568149202000
#  323977     1507 -978.0  -53.0   86.0       76.0  1568149203000
#  323978     1507 -979.0  -53.0   88.0       76.0  1568149204000
#  ...         ...    ...    ...    ...        ...            ...
#  331864     1507 -470.0  610.0 -642.0       79.0  1568159993000
#  331865     1507 -469.0  612.0 -642.0       79.0  1568159994000
#  331866     1507 -469.0  614.0 -642.0       78.0  1568159995000
#  331867     1507 -469.0  613.0 -642.0       78.0  1568159996000
#  331868     1507 -470.0  613.0 -642.0       77.0  1568159997000
#
#                           tsDate
#  323974  2019-09-10 21:00:00.267
#  323975  2019-09-10 21:00:01.279
#  323976  2019-09-10 21:00:02.296
#  323977  2019-09-10 21:00:03.314
#  323978  2019-09-10 21:00:04.340
#  ...                         ...
#  331864  2019-09-10 23:59:53.686
#  331865  2019-09-10 23:59:54.703
#  331866  2019-09-10 23:59:55.720
#  331867  2019-09-10 23:59:56.735
#  331868  2019-09-10 23:59:57.752
#
#  [7895 rows x 7 columns],
#          patient      x       y      z  heartRate     timestamp  \
#  331870   1509.0 -532.0  -250.0  812.0       78.0  1.572394e+12
#  331871   1509.0 -527.0  -255.0  812.0       80.0  1.572394e+12
#  331872   1509.0 -525.0  -259.0  813.0       77.0  1.572394e+12
#  331873   1509.0 -526.0  -260.0  814.0       77.0  1.572394e+12
#  331874   1509.0 -529.0  -260.0  811.0       74.0  1.572394e+12
#  ...         ...    ...     ...    ...        ...           ...
#  403995   1509.0  -80.0  1045.0    0.0       65.0  1.572469e+12
#  403996   1509.0  -66.0  1024.0   -8.0       65.0  1.572469e+12
#  403997   1509.0  -69.0  1024.0   -4.0       65.0  1.572469e+12
#  403998   1509.0  -63.0  1028.0  -52.0       65.0  1.572469e+12
#  403999   1509.0  -58.0  1025.0  -58.0       65.0  1.572469e+12
#
#                           tsDate
#  331870  2019-10-30 00:00:00.010
#  331871  2019-10-30 00:00:01.024
#  331872  2019-10-30 00:00:02.039
#  331873  2019-10-30 00:00:03.053
#  331874  2019-10-30 00:00:04.067
#  ...                         ...
#  403995  2019-10-30 20:59:54.775
#  403996  2019-10-30 20:59:55.784
#  403997  2019-10-30 20:59:56.792
#  403998  2019-10-30 20:59:57.801
#  403999  2019-10-30 20:59:58.809
#
#  [72130 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  404000   3506.0 -906.0  428.0   40.0       80.0  1.572415e+12
#  404001   3506.0 -904.0  418.0  -57.0       80.0  1.572415e+12
#  404002   3506.0 -640.0  504.0 -525.0       80.0  1.572415e+12
#  404003   3506.0 -575.0  666.0 -401.0       80.0  1.572415e+12
#  404004   3506.0 -683.0  675.0  328.0       80.0  1.572415e+12
#  ...         ...    ...    ...    ...        ...           ...
#  450522   3506.0  445.0  918.0  -64.0       90.0  1.572468e+12
#  450523   3506.0  465.0  887.0 -154.0       90.0  1.572468e+12
#  450524   3506.0  436.0  717.0 -485.0       91.0  1.572468e+12
#  450525   3506.0  590.0  212.0 -804.0       92.0  1.572468e+12
#  450526   3506.0  641.0  725.0  110.0       92.0  1.572468e+12
#
#                           tsDate
#  404000  2019-10-30 06:04:23.000
#  404001  2019-10-30 06:04:24.023
#  404002  2019-10-30 06:04:25.033
#  404003  2019-10-30 06:04:26.036
#  404004  2019-10-30 06:04:27.039
#  ...                         ...
#  450522  2019-10-30 20:40:36.544
#  450523  2019-10-30 20:40:37.561
#  450524  2019-10-30 20:40:38.578
#  450525  2019-10-30 20:40:39.596
#  450526  2019-10-30 20:40:40.613
#
#  [46527 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  450527   3507.0 -637.0 -447.0 -611.0       72.0  1.572394e+12
#  450528   3507.0 -635.0 -444.0 -617.0       72.0  1.572394e+12
#  450529   3507.0 -635.0 -444.0 -617.0       71.0  1.572394e+12
#  450530   3507.0 -640.0 -446.0 -610.0       70.0  1.572394e+12
#  450531   3507.0 -639.0 -445.0 -614.0       70.0  1.572394e+12
#  ...         ...    ...    ...    ...        ...           ...
#  513105   3507.0 -150.0 -739.0  688.0       70.0  1.572480e+12
#  513106   3507.0 -150.0 -737.0  690.0       69.0  1.572480e+12
#  513107   3507.0 -148.0 -739.0  688.0       70.0  1.572480e+12
#  513108   3507.0 -147.0 -739.0  689.0       70.0  1.572480e+12
#  513109   3507.0 -149.0 -738.0  690.0       68.0  1.572480e+12
#
#                           tsDate
#  450527  2019-10-30 00:00:00.002
#  450528  2019-10-30 00:00:01.007
#  450529  2019-10-30 00:00:02.013
#  450530  2019-10-30 00:00:03.019
#  450531  2019-10-30 00:00:04.024
#  ...                         ...
#  513105  2019-10-30 23:59:54.092
#  513106  2019-10-30 23:59:55.099
#  513107  2019-10-30 23:59:56.104
#  513108  2019-10-30 23:59:57.110
#  513109  2019-10-30 23:59:58.115
#
#  [62583 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  513110   3508.0 -732.0 -695.0 -136.0       84.0  1.572394e+12
#  513111   3508.0 -730.0 -697.0 -138.0       83.0  1.572394e+12
#  513112   3508.0 -728.0 -699.0 -140.0       82.0  1.572394e+12
#  513113   3508.0 -726.0 -700.0 -139.0       82.0  1.572394e+12
#  513114   3508.0 -724.0 -703.0 -139.0       82.0  1.572394e+12
#  ...         ...    ...    ...    ...        ...           ...
#  599073   3508.0 -479.0  612.0 -689.0       65.0  1.572480e+12
#  599074   3508.0 -477.0  614.0 -689.0       65.0  1.572480e+12
#  599075   3508.0 -477.0  613.0 -688.0       65.0  1.572480e+12
#  599076   3508.0 -477.0  613.0 -689.0       64.0  1.572480e+12
#  599077   3508.0 -478.0  613.0 -689.0       64.0  1.572480e+12
#
#                           tsDate
#  513110  2019-10-30 00:00:00.002
#  513111  2019-10-30 00:00:01.003
#  513112  2019-10-30 00:00:02.006
#  513113  2019-10-30 00:00:03.026
#  513114  2019-10-30 00:00:04.028
#  ...                         ...
#  599073  2019-10-30 23:59:54.237
#  599074  2019-10-30 23:59:55.239
#  599075  2019-10-30 23:59:56.240
#  599076  2019-10-30 23:59:57.242
#  599077  2019-10-30 23:59:58.243
#
#  [85968 rows x 7 columns],
#          patient       x     y      z  heartRate      timestamp  \
#  599078     3509  -652.0  31.0 -753.0       52.0  1572393600000
#  599079     3509  -653.0  30.0 -752.0       51.0  1572393601000
#  599080     3509  -649.0  31.0 -754.0       52.0  1572393602000
#  599081     3509  -649.0  32.0 -756.0       52.0  1572393603000
#  599082     3509  -651.0  31.0 -753.0       52.0  1572393604000
#  ...         ...     ...   ...    ...        ...            ...
#  611109     3509  1028.0  95.0  -53.0       54.0  1572415194000
#  611110     3509  1028.0  95.0  -52.0       54.0  1572415195000
#  611111     3509  1028.0  95.0  -52.0       54.0  1572415196000
#  611112     3509  1028.0  97.0  -53.0       54.0  1572415197000
#  611113     3509  1027.0  95.0  -52.0       54.0  1572415198000
#
#                           tsDate
#  599078  2019-10-30 00:00:00.011
#  599079  2019-10-30 00:00:01.024
#  599080  2019-10-30 00:00:02.032
#  599081  2019-10-30 00:00:03.045
#  599082  2019-10-30 00:00:04.055
#  ...                         ...
#  611109  2019-10-30 05:59:54.770
#  611110  2019-10-30 05:59:55.782
#  611111  2019-10-30 05:59:56.794
#  611112  2019-10-30 05:59:57.804
#  611113  2019-10-30 05:59:58.816
#
#  [12036 rows x 7 columns],
#          patient       x       y     z  heartRate      timestamp  \
#  618227     3509  1024.0    37.0 -30.0       74.0  1572422400000
#  618228     3509  1025.0    38.0 -30.0       74.0  1572422401000
#  618229     3509  1025.0    38.0 -30.0       74.0  1572422402000
#  618230     3509  1024.0    37.0 -30.0       74.0  1572422403000
#  618231     3509  1025.0    39.0 -30.0       74.0  1572422404000
#  ...         ...     ...     ...   ...        ...            ...
#  644745     3509  -284.0  1000.0 -12.0       60.0  1572479993000
#  644746     3509  -285.0   999.0 -12.0       60.0  1572479994000
#  644747     3509  -285.0   999.0 -11.0       61.0  1572479995000
#  644748     3509  -285.0  1000.0 -12.0       61.0  1572479996000
#  644749     3509  -285.0   999.0 -11.0       61.0  1572479997000
#
#                           tsDate
#  618227  2019-10-30 08:00:00.005
#  618228  2019-10-30 08:00:01.017
#  618229  2019-10-30 08:00:02.035
#  618230  2019-10-30 08:00:03.046
#  618231  2019-10-30 08:00:04.053
#  ...                         ...
#  644745  2019-10-30 23:59:53.817
#  644746  2019-10-30 23:59:54.828
#  644747  2019-10-30 23:59:55.838
#  644748  2019-10-30 23:59:56.849
#  644749  2019-10-30 23:59:57.859
#
#  [26523 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  644751   4502.0  229.0 -673.0  737.0       58.0  1.572394e+12
#  644752   4502.0  229.0 -675.0  738.0       58.0  1.572394e+12
#  644753   4502.0  230.0 -673.0  737.0       58.0  1.572394e+12
#  644754   4502.0  229.0 -674.0  737.0       57.0  1.572394e+12
#  644755   4502.0  229.0 -673.0  737.0       57.0  1.572394e+12
#  ...         ...    ...    ...    ...        ...           ...
#  727107   4502.0 -864.0 -385.0 -255.0       54.0  1.572480e+12
#  727108   4502.0 -865.0 -385.0 -251.0       54.0  1.572480e+12
#  727109   4502.0 -863.0 -388.0 -256.0       54.0  1.572480e+12
#  727110   4502.0 -862.0 -388.0 -256.0       51.0  1.572480e+12
#  727111   4502.0 -863.0 -386.0 -253.0       50.0  1.572480e+12
#
#                           tsDate
#  644751  2019-10-30 00:00:00.005
#  644752  2019-10-30 00:00:01.013
#  644753  2019-10-30 00:00:02.020
#  644754  2019-10-30 00:00:03.029
#  644755  2019-10-30 00:00:04.036
#  ...                         ...
#  727107  2019-10-30 23:59:54.390
#  727108  2019-10-30 23:59:55.398
#  727109  2019-10-30 23:59:56.405
#  727110  2019-10-30 23:59:57.414
#  727111  2019-10-30 23:59:58.421
#
#  [82361 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  727112     4504 -184.0 -635.0  776.0       68.0  1572393600000
#  727113     4504 -185.0 -635.0  775.0       68.0  1572393601000
#  727114     4504 -186.0 -636.0  775.0       68.0  1572393602000
#  727115     4504 -185.0 -634.0  775.0       68.0  1572393603000
#  727116     4504 -184.0 -632.0  774.0       68.0  1572393604000
#  ...         ...    ...    ...    ...        ...            ...
#  750432     4504 -935.0 -252.0   76.0       63.0  1572447593000
#  750433     4504 -936.0 -253.0   77.0       63.0  1572447594000
#  750434     4504 -936.0 -252.0   76.0       63.0  1572447595000
#  750435     4504 -936.0 -252.0   76.0       63.0  1572447596000
#  750436     4504 -935.0 -251.0   76.0       63.0  1572447598000
#
#                           tsDate
#  727112  2019-10-30 00:00:00.016
#  727113  2019-10-30 00:00:01.017
#  727114  2019-10-30 00:00:02.037
#  727115  2019-10-30 00:00:03.057
#  727116  2019-10-30 00:00:04.076
#  ...                         ...
#  750432  2019-10-30 14:59:53.936
#  750433  2019-10-30 14:59:54.956
#  750434  2019-10-30 14:59:55.976
#  750435  2019-10-30 14:59:56.993
#  750436  2019-10-30 14:59:58.013
#
#  [23325 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  761031     4504 -937.0 -250.0   69.0       73.0  1572458400000
#  761032     4504 -937.0 -252.0   69.0       73.0  1572458401000
#  761033     4504 -937.0 -252.0   69.0       73.0  1572458402000
#  761034     4504 -937.0 -251.0   69.0       73.0  1572458403000
#  761035     4504 -937.0 -252.0   70.0       73.0  1572458404000
#  ...         ...    ...    ...    ...        ...            ...
#  782259     4504 -239.0  960.0 -184.0       69.0  1572479993000
#  782260     4504 -241.0  960.0 -186.0       69.0  1572479994000
#  782261     4504 -241.0  959.0 -184.0       69.0  1572479995000
#  782262     4504 -240.0  960.0 -183.0       70.0  1572479996000
#  782263     4504 -241.0  960.0 -186.0       70.0  1572479997000
#
#                           tsDate
#  761031  2019-10-30 18:00:00.003
#  761032  2019-10-30 18:00:01.022
#  761033  2019-10-30 18:00:02.040
#  761034  2019-10-30 18:00:03.060
#  761035  2019-10-30 18:00:04.080
#  ...                         ...
#  782259  2019-10-30 23:59:53.338
#  782260  2019-10-30 23:59:54.356
#  782261  2019-10-30 23:59:55.376
#  782262  2019-10-30 23:59:56.394
#  782263  2019-10-30 23:59:57.396
#
#  [21233 rows x 7 columns],
#          patient      x      y      z  heartRate      timestamp  \
#  782265     4505 -514.0  266.0 -815.0       57.0  1572393600000
#  782266     4505 -521.0  266.0 -811.0       57.0  1572393601000
#  782267     4505 -516.0  268.0 -814.0       57.0  1572393602000
#  782268     4505 -515.0  266.0 -816.0       57.0  1572393603000
#  782269     4505 -515.0  270.0 -814.0       56.0  1572393604000
#  ...         ...    ...    ...    ...        ...            ...
#  850160     4505 -992.0   40.0   52.0       48.0  1572465594000
#  850161     4505 -992.0   40.0   52.0       48.0  1572465595000
#  850162     4505 -990.0   39.0   52.0       48.0  1572465596000
#  850163     4505 -991.0   39.0   53.0       48.0  1572465597000
#  850164     4505 -991.0   39.0   52.0       48.0  1572465598000
#
#                           tsDate
#  782265  2019-10-30 00:00:00.007
#  782266  2019-10-30 00:00:01.014
#  782267  2019-10-30 00:00:02.019
#  782268  2019-10-30 00:00:03.024
#  782269  2019-10-30 00:00:04.030
#  ...                         ...
#  850160  2019-10-30 19:59:54.244
#  850161  2019-10-30 19:59:55.248
#  850162  2019-10-30 19:59:56.251
#  850163  2019-10-30 19:59:57.257
#  850164  2019-10-30 19:59:58.261
#
#  [67900 rows x 7 columns],
#          patient      x     y       z  heartRate      timestamp  \
#  853724     4505 -994.0  39.0    52.0       76.0  1572469200000
#  853725     4505 -993.0  38.0    52.0       76.0  1572469201000
#  853726     4505 -992.0  39.0    52.0       76.0  1572469202000
#  853727     4505 -991.0  39.0    52.0       76.0  1572469203000
#  853728     4505 -992.0  39.0    52.0       76.0  1572469204000
#  ...         ...    ...   ...     ...        ...            ...
#  864443     4505   -2.0  84.0  1082.0       50.0  1572479993000
#  864444     4505   -3.0  83.0  1082.0       50.0  1572479994000
#  864445     4505   -3.0  84.0  1082.0       50.0  1572479995000
#  864446     4505   -4.0  78.0  1085.0       50.0  1572479996000
#  864447     4505  -26.0  74.0  1077.0       50.0  1572479997000
#
#                           tsDate
#  853724  2019-10-30 21:00:00.006
#  853725  2019-10-30 21:00:01.010
#  853726  2019-10-30 21:00:02.022
#  853727  2019-10-30 21:00:03.032
#  853728  2019-10-30 21:00:04.043
#  ...                         ...
#  864443  2019-10-30 23:59:53.810
#  864444  2019-10-30 23:59:54.815
#  864445  2019-10-30 23:59:55.822
#  864446  2019-10-30 23:59:56.827
#  864447  2019-10-30 23:59:57.834
#
#  [10724 rows x 7 columns],
#          patient      x      y      z  heartRate     timestamp  \
#  864449   4506.0 -818.0 -567.0 -133.0       58.0  1.572394e+12
#  864450   4506.0 -818.0 -568.0 -132.0       57.0  1.572394e+12
#  864451   4506.0 -818.0 -567.0 -130.0       56.0  1.572394e+12
#  864452   4506.0 -818.0 -567.0 -132.0       57.0  1.572394e+12
#  864453   4506.0 -819.0 -568.0 -134.0       57.0  1.572394e+12
#  ...         ...    ...    ...    ...        ...           ...
#  943517   4506.0 -636.0 -399.0 -654.0       57.0  1.572480e+12
#  943518   4506.0 -639.0 -396.0 -654.0       57.0  1.572480e+12
#  943519   4506.0 -638.0 -396.0 -655.0       57.0  1.572480e+12
#  943520   4506.0 -637.0 -396.0 -655.0       58.0  1.572480e+12
#  943521   4506.0 -636.0 -399.0 -656.0       58.0  1.572480e+12
#
#                           tsDate
#  864449  2019-10-30 00:00:00.007
#  864450  2019-10-30 00:00:01.008
#  864451  2019-10-30 00:00:02.009
#  864452  2019-10-30 00:00:03.010
#  864453  2019-10-30 00:00:04.011
#  ...                         ...
#  943517  2019-10-30 23:59:54.315
#  943518  2019-10-30 23:59:55.316
#  943519  2019-10-30 23:59:56.336
#  943520  2019-10-30 23:59:57.337
#  943521  2019-10-30 23:59:58.338
#
#  [79073 rows x 7 columns]]

# %%
new_data[0].head(20)
# Out:
#       patient     x      y      z  heartRate      timestamp  \
# 7120     1502  23.0  570.0  878.0       84.0  1568080800000
# 7121     1502  23.0  571.0  878.0       84.0  1568080801000
# 7122     1502  23.0  571.0  878.0       84.0  1568080802000
# 7123     1502  23.0  571.0  877.0       84.0  1568080803000
# 7124     1502  23.0  571.0  878.0       84.0  1568080804000
# 7125     1502  23.0  571.0  878.0       84.0  1568080805000
# 7126     1502  23.0  571.0  877.0       84.0  1568080806000
# 7127     1502  23.0  570.0  877.0       84.0  1568080807000
# 7128     1502  23.0  571.0  878.0       84.0  1568080808000
# 7129     1502  23.0  570.0  876.0       84.0  1568080809000
# 7130     1502  23.0  572.0  877.0       84.0  1568080810000
# 7131     1502  22.0  571.0  877.0       84.0  1568080811000
# 7132     1502  23.0  571.0  878.0       84.0  1568080812000
# 7133     1502  23.0  571.0  877.0       84.0  1568080813000
# 7134     1502  23.0  571.0  878.0       84.0  1568080814000
# 7135     1502  24.0  571.0  877.0       84.0  1568080815000
# 7136     1502  23.0  571.0  878.0       84.0  1568080816000
# 7137     1502  24.0  571.0  877.0       84.0  1568080817000
# 7138     1502  23.0  571.0  877.0       84.0  1568080818000
# 7139     1502  24.0  570.0  878.0       84.0  1568080819000
#
#                        tsDate
# 7120  2019-09-10 02:00:00.000
# 7121  2019-09-10 02:00:01.010
# 7122  2019-09-10 02:00:02.022
# 7123  2019-09-10 02:00:03.033
# 7124  2019-09-10 02:00:04.376
# 7125  2019-09-10 02:00:05.392
# 7126  2019-09-10 02:00:06.402
# 7127  2019-09-10 02:00:07.413
# 7128  2019-09-10 02:00:08.423
# 7129  2019-09-10 02:00:09.434
# 7130  2019-09-10 02:00:10.444
# 7131  2019-09-10 02:00:11.455
# 7132  2019-09-10 02:00:12.466
# 7133  2019-09-10 02:00:13.476
# 7134  2019-09-10 02:00:14.487
# 7135  2019-09-10 02:00:15.497
# 7136  2019-09-10 02:00:16.507
# 7137  2019-09-10 02:00:17.518
# 7138  2019-09-10 02:00:18.528
# 7139  2019-09-10 02:00:19.539

# %% [markdown]
# ##### **Patient series split**
# Nella cella sottostante verrà ricreato l'array con le sequenze per ogni paziente dove però le series dei pazienti con dei valori di "Heartrate" a -1 verranno considerate come due series: una a sinistra dei valori di "-1" ed una a destra dei valori di "-1"

# %%
for rows_index in range(0,len(new_data)):
  
    new_data[rows_index] = new_data[rows_index].drop(columns=["patient","timestamp","tsDate"])
    new_data[rows_index] = new_data[rows_index].rolling(10).mean()

    new_data[rows_index] = new_data[rows_index][::10].dropna()

# %%
new_data[0].head(20)
# Out:
#          x      y      z  heartRate
# 7130  23.0  570.9  877.4       84.0
# 7140  23.2  570.9  877.4       84.0
# 7150  22.9  570.7  877.6       84.0
# 7160  23.0  570.8  877.1       84.0
# 7170  23.0  570.6  877.4       84.0
# 7180  23.2  570.9  877.8       84.0
# 7190  23.2  570.9  877.4       84.0
# 7200  23.2  570.3  877.4       84.0
# 7210  23.1  570.8  877.6       84.0
# 7220  22.9  570.9  877.4       84.0
# 7230  23.0  570.8  877.5       84.0
# 7240  23.3  570.5  877.2       84.0
# 7250  23.3  570.9  877.7       84.0
# 7260  23.1  570.2  878.3       84.0
# 7270  23.2  570.6  877.3       84.0
# 7280  23.1  570.6  877.3       84.0
# 7290  22.7  571.0  877.6       84.0
# 7300  23.3  570.5  877.2       84.0
# 7310  22.9  570.6  877.6       84.0
# 7320  23.3  570.6  877.5       84.0

# %%
test_data_loaded = [d for _, d in test_data_loaded.groupby(['patient'])]

# %%
for id in test_data_loaded:
    id.index = np.arange(0, len(id))

# %%
test_data_copy = test_data_loaded

# %% [markdown]
# ##### **Trainset normalization**

# %%
mean_test = 0
std_test = 0
for rows_index in range(0,len(new_data)):
    mean_test += new_data[rows_index].mean()
    std_test += new_data[rows_index].std()

mean_test = mean_test / len(new_data)
std_test = std_test / len(new_data)

test_data = []
for id in test_data_loaded:
    patient_rows = id.drop(columns=['patient','timestamp','tsDate'])
    patient_rows = (patient_rows - mean_test) / std_test
    test_data.append(patient_rows)

# %%
for rows_index in range(0,len(new_data)):
    mean = new_data[rows_index].mean()
    std = new_data[rows_index].std()

    new_data[rows_index] = (new_data[rows_index] - mean)/std

# %%
new_data[0].head(20)
# Out:
#              x         y         z  heartRate
# 7130  0.220730  0.333616  2.549764   0.936616
# 7140  0.221095  0.333616  2.549764   0.936616
# 7150  0.220547  0.333252  2.550221   0.936616
# 7160  0.220730  0.333434  2.549079   0.936616
# 7170  0.220730  0.333070  2.549764   0.936616
# 7180  0.221095  0.333616  2.550678   0.936616
# 7190  0.221095  0.333616  2.549764   0.936616
# 7200  0.221095  0.332524  2.549764   0.936616
# 7210  0.220912  0.333434  2.550221   0.936616
# 7220  0.220547  0.333616  2.549764   0.936616
# 7230  0.220730  0.333434  2.549992   0.936616
# 7240  0.221277  0.332888  2.549307   0.936616
# 7250  0.221277  0.333616  2.550449   0.936616
# 7260  0.220912  0.332343  2.551820   0.936616
# 7270  0.221095  0.333070  2.549535   0.936616
# 7280  0.220912  0.333070  2.549535   0.936616
# 7290  0.220182  0.333797  2.550221   0.936616
# 7300  0.221277  0.332888  2.549307   0.936616
# 7310  0.220547  0.333070  2.550221   0.936616
# 7320  0.221277  0.333070  2.549992   0.936616

# %%
for d in new_data:
    print(d.shape)

print(max(d.shape[0] for d in new_data))
# Out:
# (7812, 4)
# (8263, 4)
# (4973, 4)
# (3086, 4)
# (6484, 4)
# (789, 4)
# (7212, 4)
# (4652, 4)
# (6258, 4)
# (8596, 4)
# (1203, 4)
# (2652, 4)
# (8236, 4)
# (2332, 4)
# (2123, 4)
# (6789, 4)
# (1072, 4)
# (7907, 4)
# 8596

# %% [markdown]
# ##### **Data Windowing**
# Le due funzioni sottostanti verranno utilizzate rispettivamente dal training set e dal test set. La prima funzione tornerà un'array di sequenze raccolte da ogni paziente. La seconda funzione tornerà un'array di sequenze di quel solo paziente

# %%
def data_windowing(data, lookback, step):
    
    patient_series = []

    for patient_id_index in range(0,len(data)):
        for i in range(0, len(data[patient_id_index]) - lookback - 1, step):
            patient_series.append(data[patient_id_index][i: i + lookback])
      
    patient_series = np.array(patient_series)
    patient_series = patient_series.reshape((patient_series.shape[0], patient_series.shape[1], 4))
    return patient_series

def data_windowing_test(data, lookback, step):
    
    patient_series = []
    
    for i in range(0, len(data) - lookback - 1, step):
        patient_series.append(data[i: i + lookback])
      
    patient_series = np.array(patient_series)
    patient_series = patient_series.reshape((patient_series.shape[0], patient_series.shape[1], 4))
    return patient_series

# %% [markdown]
# ##### **Validation data split**

# %%
val_data = []
train_data = []
for data in new_data:
  
    len_split = round(data.shape[0]*0.7)
  
    train_data.append(data[:len_split])
    val_data.append(data[len_split:])

# %%
win_size = 30
win_shift = 1

x_train = data_windowing(train_data, win_size, win_shift)
x_val = data_windowing(val_data, win_size, win_shift)

seq_test = []
for p in test_data:
    seq_test.append(data_windowing_test(p, win_size, win_shift))

# %%
x_train.shape
# Out:
# (62746, 30, 4)

# %%
x_val.shape
# Out:
# (26577, 30, 4)

# %% [markdown]
# ## **Modeling**

# %%
#pip install keras-tuner --upgrade

# %%
import tensorflow as tf
from tensorflow.keras import models, layers

import keras_tuner as kt

my_seed = 44
np.random.seed(my_seed)
tf.random.set_seed(my_seed)

# %%
seq_len = x_train.shape[1]
num_feat = x_train.shape[2]

# %% [markdown]
# ##### **Create the models**
# Per quanto riguarda gli hyperparameters sul numero di neuroni e sul learning rate verrà effettuata una ricerca attraverso un hypertuner per riuscire a ricostruire quello che sarà il best model. Il modello che siamo interessati a creare è un autoencoder che utilizza come layer "LSTM", "Dropout", "RepeatVector" e "TimeDistributed".

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(112, input_shape=(seq_len, num_feat)))
model.add(layers.Dropout(rate=0.2))
model.add(layers.RepeatVector(seq_len))
model.add(layers.LSTM(112, return_sequences=True))
model.add(layers.Dropout(rate=0.2))
model.add(layers.TimeDistributed(layers.Dense(num_feat)))
# Tune the learning rate for the optimizer
# Choose an optimal value from 0.01, 0.001, or 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), loss = 'mae')

# %%
history = model.fit(x_train, x_train, epochs=20, validation_data=(x_val,x_val))
# Out:
# Epoch 1/20
#  222/1961 [==>...........................] - ETA: 1:07 - loss: 0.4124

# %%
loss_per_epoch = history.history['loss']
best_epoch = loss_per_epoch.index(min(loss_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))

# %% [markdown]
# ##### Retrain the model
# Ricostruzione del best model sulla base degli hyperparameters ottimali trovati (numero di neuroni, learning rate e miglior minor numero di epoche)

# %%
# Plotting results

import matplotlib.pyplot as plt

loss = history.history['loss'] 
epochs = range(len(loss))

plt.plot(epochs, loss,  label='Training loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(112, input_shape=(seq_len, num_feat)))
model.add(layers.Dropout(rate=0.2))
model.add(layers.RepeatVector(seq_len))
model.add(layers.LSTM(112, return_sequences=True))
model.add(layers.Dropout(rate=0.2))
model.add(layers.TimeDistributed(layers.Dense(num_feat)))
# Tune the learning rate for the optimizer
# Choose an optimal value from 0.01, 0.001, or 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), loss = 'mae')

# %%
history = model.fit(x_train, x_train, epochs=12, validation_data=(x_val,x_val))

# %%
# Plotting results

import matplotlib.pyplot as plt

loss = history.history['loss'] 
epochs = range(len(loss))

plt.plot(epochs, loss,  label='Training loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %% [markdown]
# ## *Prediction*
# Per ogni paziente nel testset verrà effettuata una predizione su ogni riga di ogni sequenza costruita. Per ognuno di questa riga di ogni sequenza verrà calcolato e salvato il "Mean Absolute Error".

# %%
from sklearn.metrics import mean_absolute_error
import time
start_total = time.time()
p_errors = []
for seq in seq_test:
    index = 1
    start = time.time()
    mae_record = []
    for i in range(0, len(seq)):
        #print("Predicting seq " + str(i) + " for patient " + str(index))
        mae_seq = []
        prediction = hypermodel.predict(seq[[i]], verbose = 0)
        for j in range(0, prediction.shape[1]):
            #print("Calculating mae for row " + str(j))
            mae = 0
            mae = mean_absolute_error(seq[0][[j]], prediction[0][[j]])
            mae_seq.append(mae)
        mae_record.append(mae_seq)
    p_errors.append(mae_record)
    print("Ended seq " + str(index) + " in " + str(time.time()-start))
end_total = time.time()
print(end_total-start_total)

# %% [markdown]
# #### *Metrics*
#
# L'indice di "mae" ottenuto dalla predizione su ogni riga di ogni sequenza di ogni paziente è "compresso" come somma in modo da non avere risultati doppioni da queste predizioni.

# %%
patient_mae_per_row = {}
for i in range(0, len(p_errors)):
    patient_mae_per_row[i] = np.zeros(len(p_errors[i]))
    for j in range(0, len(p_errors[i])- win_size - 1):
        for k in range(0, len(p_errors[i][j])):
            patient_mae_per_row[i][j+k] += p_errors[i][j][k]

# %%
for i in range(0, len(p_errors)):
    for j in range(0, len(p_errors[i])):
        if j < win_size - 1:
            patient_mae_per_row[i][j] = patient_mae_per_row[i][j]/(j+1)
        elif j > len(p_errors[i]) - win_size:
            patient_mae_per_row[i][j] = patient_mae_per_row[i][j]/(len(p_errors[i])-j)
        else:
            patient_mae_per_row[i][j] = patient_mae_per_row[i][j]/win_size

# %% [markdown]
# ## *Evaluation*
#
# Per ogni paziente viene mostrato il grafico con l'andamento dell'errore calcolato dalle predizioni. Su di ognuno di questi andamenti vengono considerati come "off period" quei valori di errori che si avvicinano al 95% dell'errore massimo.

# %%
tresholds = []
for p in range(0, len(patient_mae_per_row)):
    er_max = max(patient_mae_per_row[p])
    print(er_max)
    print("----")
    tr = ((er_max) / 10 * 9.5)
    tresholds.append(tr)
    plt.plot(range(len(patient_mae_per_row[p])), patient_mae_per_row[p],  label='Error')
    plt.axhline(tr, color='r')
    plt.title('Error') 
    plt.xlabel('Record')
    plt.ylabel('Loss') 
    plt.legend()
    plt.show()

# %% [markdown]
# ##### Saving result
# I momenti di off-period vengono salvati in un file .csv contenente le colonne di "patient" (id del paziente), "tsDate" (momento e ora dell'offperiod) e "off" (stringa "True" che attesta questo avvenimento)

# %%
test_data_copy

f = open("off_period.csv", "w")
f.write("patient, tsDate, off\n")

for p in range(len(patient_mae_per_row)):
    for er in range(len(patient_mae_per_row[p])):
        if patient_mae_per_row[p][er] > tresholds[p]:
            row = str(test_data_copy[p].iloc[er]['patient']) + "," + str(test_data_copy[p].iloc[er]['tsDate']) + ", True\n"
            f.write(row)
f.close()
